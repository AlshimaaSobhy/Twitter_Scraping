# %% [markdown]
# Importing necessary data

# %%
import tweepy
import csv
import time
import pandas as pd
import re
from pymongo import MongoClient
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter as DF

# %% [markdown]
# Identify keywords related to AI

# %%
ai_keywords = [
    "NLP", 
    "AI", 
    "Artificial Intelligence", 
    "Chatgpt", 
    "Deepseek", 
    "CV"
]

# %% [markdown]
# # Data Extraction

# %% [markdown]
# Requsting tweets using tweepy

# %%
bearer_token = r"AAAAAAAAAAAAAAAAAAAAAHwn0wEAAAAA%2BXtWl8lg1EhNvP3aIdbuvW2WOCc%3Dw8DzG3cOB9diVNKfi5qUvMHTjZ42lzmHvDXnjob4Jbq8vPuVW3"

# %%
client = tweepy.Client(bearer_token= bearer_token)

# %% [markdown]
# Reading tweets

# %%
with open("ai_tweets.csv", 'a', newline='', encoding='utf-8-sig') as file:  # creating csv file
    writer= csv.writer(file)
    writer.writerow(['Tweet', 'created_at'])
    
    for keyword in ai_keywords:
        try: # Requesting tweets based on keywords (English tweets)
            tweets = client.search_recent_tweets(
                query = f' "{keyword}" lang:en -is:retweet', 
                max_results = 10,
                tweet_fields =['created_at', 'text']  # I requset the text and the date the tweets created at
            )
            
            if tweets.data:  #Store tweets in the csv file
                for tweet in tweets.data:
                    writer.writerow([tweet.text, tweet.created_at,])
            time.sleep(10)
            
        except Exception as e:
            print(f'Error fetching for {keyword} : ', e)
# Out:
# Error fetching for NLP :  'Database' object is not callable
# Error fetching for Natural Language Processing :  'Database' object is not callable
# Error fetching for Text :  'Database' object is not callable
# Error fetching for Language model :  'Database' object is not callable
# Error fetching for Computer Vision :  'Database' object is not callable
# Error fetching for Image :  'Database' object is not callable
# Error fetching for YOLO :  'Database' object is not callable
# Error fetching for ResNet :  'Database' object is not callable
# Error fetching for Object detection :  'Database' object is not callable

# %% [markdown]
# Reading dataset

# %%
df = pd.read_csv("ai_tweets.csv", encoding='ISO-8859-1')
print(f"Total rows: {len(df)}")
# Out:
# Total rows: 151677

# %% [markdown]
# -----------------

# %% [markdown]
# # Cleaning

# %%
df = df[~df['created_at'].astype(str).str.contains("Time", na=False)]
df['created_at'] = pd.to_datetime(df['created_at'], errors='coerce')
df = df[df['created_at'].notna()]

df.drop_duplicates(inplace=True)

df.dropna(subset=['Tweet', 'created_at'], inplace=True)

# %%
def clean_text(text):
    text = str(text)
    text = re.sub(r"http\S+", "", text)  
    text = re.sub(r"@\w+", "", text)    
    text = re.sub(r"#\w+", "", text)     
    text = re.sub(r"[^\w\s]", "", text)  
    text = re.sub(r"\s+", " ", text)     
    return text.strip().lower()

# %%
df['cleaned_text'] = df['Tweet'].apply(clean_text)
df.drop_duplicates(subset=['cleaned_text'], inplace=True)

df['Tweet'] = df['cleaned_text']
df.drop(columns=['cleaned_text'], inplace=True)

df.head()
# Out:
#                                                Tweet created_at
# 0  invest in a currency that is designed to offer... 2025-03-14
# 1  while having all the hope around chatgpt lets ... 2025-03-14
# 2  join the movement towards a more sustainable a... 2025-03-14
# 3  theres a snowstorm out so naturally i decided ... 2025-03-14
# 4  invest in a currency that offers a more secure... 2025-03-14

# %%
df.shape
# Out:
# (123746, 2)

# %%
na_counts = df.isna().sum()
print(na_counts)
# Out:
# Tweet         0
# created_at    0
# dtype: int64

# %%
duplicate_counts = df.duplicated().sum()
duplicate_counts
# Out:
# 0

# %% [markdown]
# Storing data to MongoDB after cleaning

# %%
client = MongoClient('mongodb://localhost:27017/')  
db = client['ai_tweets_db']  
collection = db['tweets']  
data_dict = df.to_dict("records")
#   checking if the data already exists
if collection.count_documents({}) == 0:
    collection.insert_many(data_dict)
    print("The data has been stored in MongoDB.")
else:
    print("Data already exists in MongoDB. Skipping insert.")
# Out:
# Data already exists in MongoDB. Skipping insert.

# %% [markdown]
# Displaying number of docs

# %%
count = collection.count_documents({})
print(f"num. of docs.: {count}")
# Out:
# num. of docs.: 123746

# %% [markdown]
# -------------

# %% [markdown]
# # Sentiment analysis

# %%
# loading data From MogoDB to DataFrame
df = pd.DataFrame(list(collection.find()))

# %%
if '_id' in df.columns: #removing ID column since it will cause an issue 
    df.drop(columns=['_id'], inplace=True)

# %%
vader = SentimentIntensityAnalyzer() #Initialize VADER

# %% [markdown]
# Functions for sentiment

# %%
def analyze_vader(txt):
    score = vader.polarity_scores(txt)
    return score['compound']

# %%
def analyze_textblob(txt):
    return TextBlob(txt).sentiment.polarity

# %% [markdown]
# Apply sentiment analysis

# %%
df['vader_score'] = df['Tweet'].apply(analyze_vader)
df['textblob_score'] = df['Tweet'].apply(analyze_textblob)

# %%
df.head(20)
# Out:
#                                                 Tweet created_at  vader_score  \
# 0   invest in a currency that is designed to offer... 2025-03-14       0.5994
# 1   while having all the hope around chatgpt lets ... 2025-03-14       0.5523
# 2   join the movement towards a more sustainable a... 2025-03-14       0.7479
# 3   theres a snowstorm out so naturally i decided ... 2025-03-14       0.0000
# 4   invest in a currency that offers a more secure... 2025-03-14       0.4005
# 5                 robots will take over the world ððð 2025-03-14       0.0000
# 6   join the community of investors who are commit... 2025-03-14       0.5106
# 7   âready to start saving lots of time with â max... 2025-03-14       0.7003
# 8                     not sure if wrote this articleâ 2025-03-14      -0.2411
# 9                                          news alert 2025-03-14       0.2960
# 10  invest in a currency that is built on a founda... 2025-03-14       0.4019
# 11                                     is avalible on 2025-03-14       0.0000
# 12                  please find the full article here 2025-03-14       0.3182
# 13  new show from lost and watchman show runner da... 2025-03-14       0.4019
# 14  join the movement towards a more inclusive and... 2025-03-14       0.7906
# 15  3 ways chatgpt will change the future of b2b c... 2025-03-14       0.0000
# 16  unlike is running gpt4 optimized mostly for se... 2025-03-14       0.5859
# 17  3 4 has 1 trillion parameters making it one of... 2025-03-14       0.0000
# 18  invest in a currency that offers a more innova... 2025-03-14       0.8204
# 19  tune in 5 mins after the top of each hour for ... 2025-03-14       0.2023
#
#    sentiment  textblob_score
# 0   Positive        0.166667
# 1   Positive       -0.125000
# 2   Positive        0.233333
# 3    Neutral        0.100000
# 4   Positive        0.250000
# 5    Neutral        0.000000
# 6   Positive        0.000000
# 7   Positive        0.400000
# 8   Negative       -0.250000
# 9   Positive        0.000000
# 10  Positive        0.000000
# 11   Neutral        0.000000
# 12  Positive        0.350000
# 13  Positive        0.252841
# 14  Positive        0.183333
# 15   Neutral        0.000000
# 16  Positive        0.295833
# 17   Neutral        0.000000
# 18  Positive        0.220000
# 19  Positive        0.375000

# %%
df.tail(20)
# Out:
#                                                     Tweet created_at  \
# 123726  deepseek said something that made me feel like... 2025-04-19
# 123727  chatgpt helped me with my homework and now iâm... 2025-02-16
# 123728  deepseek told me the truth i wasnât ready to h... 2025-04-15
# 123729  chatgpt is too good at answering questions is ... 2025-03-16
# 123730  deepseekâs out here changing my life with pred... 2025-02-05
# 123731  chatgpt helped me plan my life but iâm still w... 2025-03-28
# 123732  deepseek saw my mistakes before i did itâs hon... 2025-03-12
# 123733  chatgpt just made me realize iâve been living ... 2025-03-31
# 123734  deepseek knows more about trends than i do iâm... 2025-02-09
# 123735  chatgpt is basically a walking talking brain i... 2025-03-30
# 123736  deepseekâs predictions are so accurate iâm sta... 2025-02-15
# 123737  chatgpt do you ever take a break youâre answer... 2025-02-04
# 123738  deepseek is the ai version of a fortune cookie... 2025-03-07
# 123739  chatgpt made me realize iâm way too behind on ... 2025-04-20
# 123740  deepseek is like a personal assistant that nev... 2025-03-19
# 123741  chatgpt answered my question before i even ask... 2025-02-28
# 123742  deepseek predicted my future like itâs living ... 2025-03-10
# 123743  chatgpt made me feel like iâve been missing ou... 2025-04-21
# 123744  deepseek is so smart it should probably be run... 2025-02-01
# 123745  chatgptâs always there when i need help with m... 2025-03-03
#
#         vader_score sentiment  textblob_score
# 123726       0.1901  Positive       -0.400000
# 123727      -0.1027  Negative        0.000000
# 123728       0.7717  Positive        0.200000
# 123729       0.4404  Positive        0.150000
# 123730       0.0000   Neutral        0.000000
# 123731       0.5499  Positive        0.000000
# 123732      -0.4385  Negative        0.800000
# 123733       0.0000   Neutral        0.000000
# 123734       0.0000   Neutral        0.500000
# 123735       0.4019  Positive        0.000000
# 123736       0.0000   Neutral        0.200000
# 123737       0.0000   Neutral        0.000000
# 123738       0.0000   Neutral        0.450000
# 123739       0.0000   Neutral       -0.100000
# 123740       0.5118  Positive        0.300000
# 123741       0.0000   Neutral        0.000000
# 123742       0.3612  Positive        0.000000
# 123743       0.0772  Positive        0.045455
# 123744       0.5410  Positive        0.214286
# 123745       0.4019  Positive        0.000000

# %% [markdown]
# Add sentiment labels ('Positive', 'Neutral', 'Negative')

# %%
def label_sentiment(score):
    if score >= 0.05:
        return 'Positive'
    
    elif score <= -0.05:
        return 'Negative'
    
    else: 
        return 'Neutral'

# %%
df['sentiment'] = df['vader_score'].apply(label_sentiment)
df.drop(columns=['textblob_score'], inplace=True)
df.head()
# Out:
#                                                Tweet created_at  vader_score  \
# 0  invest in a currency that is designed to offer... 2025-03-14       0.5994
# 1  while having all the hope around chatgpt lets ... 2025-03-14       0.5523
# 2  join the movement towards a more sustainable a... 2025-03-14       0.7479
# 3  theres a snowstorm out so naturally i decided ... 2025-03-14       0.0000
# 4  invest in a currency that offers a more secure... 2025-03-14       0.4005
#
#   sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3   Neutral
# 4  Positive

# %% [markdown]
# Store back to MongoDB

# %%
collection.drop() # drop old collection to avoid duplicates
collection.insert_many(df.to_dict('records'))
print('Add & Saved to MogoDB')
# Out:
# Add & Saved to MogoDB

# %% [markdown]
# ------------

# %% [markdown]
# Comparing the average NLP & CV Sentiment

# %%
nlp_keywords = ['NLP', 'Natural Language Processing', 'Text', 'Language model']
cv_keywords = ['Computer Vision', 'Image', 'YOLO', 'ResNet', 'Object detection']

# %%
#Filter NLP & CV tweets
nlp_tweets = df[df['Tweet'].str.contains('|'.join(nlp_keywords), case=False, na=False)]
cv_tweets = df[df['Tweet'].str.contains('|'.join(cv_keywords), case=False, na=False)]

# %%
print(f'NLP: {nlp_tweets.shape}')
print(f'CV: {cv_tweets.shape}')
# Out:
# NLP: (4011, 4)
# CV: (1280, 4)

# %%
#Compute average sentiment for both NLP & CV
avg_nlp_sentiment  = label_sentiment(nlp_tweets['vader_score'].mean())
avg_cv_sentiment = label_sentiment(cv_tweets['vader_score'].mean())

# %%
#Compute the most common sentiment 
common_nlp_sentiment = df['sentiment'].mode()[0]
common_cv_sentiment = df['sentiment'].mode()[0]

# %%
#Sentiment counts
nlp_sentiment  = nlp_tweets['sentiment'].value_counts().to_dict()
cv_sentiment = cv_tweets['sentiment'].value_counts().to_dict()

# %%
# Storing results in DataFrame for later visualization
data = {
    'Metric': ['Average Sentiment', 'Most Common Sentiment', 'Positive Tweets Counts', 'Neutral Tweets Counts', 'Negative Tweets Counts' , 'No tweets'],
    'NLP': [avg_nlp_sentiment, common_nlp_sentiment, nlp_sentiment['Positive'], nlp_sentiment['Neutral'], nlp_sentiment['Negative'], len(nlp_tweets)],
    'CV': [avg_cv_sentiment, common_cv_sentiment, cv_sentiment['Positive'], cv_sentiment['Neutral'], cv_sentiment['Negative'], len(cv_tweets)]
}

npl_cv_df = pd.DataFrame(data)
npl_cv_df
# Out:
#                    Metric       NLP        CV
# 0       Average Sentiment  Positive  Positive
# 1   Most Common Sentiment  Positive  Positive
# 2  Positive Tweets Counts      2699       838
# 3   Neutral Tweets Counts       838       324
# 4  Negative Tweets Counts       474       118
# 5               No tweets      4011      1280

# %% [markdown]
# ----

# %% [markdown]
# Analyze sentiment upon specific events

# %%
events = {
    'ChatGPT Homework surge': {'Start_Date': '2025-02-12', 'End_Date': '2025-02-18', "keyword": ['ChatGPT', 'homework']},
    'AI Crypto Hype': {'Start_Date': '2025-03-12', 'End_Date': '2025-03-16', 'keyword': ["invest", "crypto", "AI"]}
}

# %%
def analyze_events(event_name, start_date, end_date, keywords):
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    
    #Filter tweets by date and key words
    event_tweets = df[(df['created_at'] >= start) & 
                      (df['created_at'] <= end) & 
                      df['Tweet'].str.contains('|'.join(keywords), case= False, na=False)]
    
    # Calculate metrics 
    avg_sentiment = event_tweets['vader_score'].mean()
    sentiment_counts = event_tweets['sentiment'].value_counts().to_dict()
    
    return{
         "Event": event_name,
        "Avg_Sentiment": avg_sentiment,
        "Sentiment_Label": label_sentiment(avg_sentiment),
        "Positive_Tweets": sentiment_counts.get('Positive', 0),
        "Neutral_Tweets": sentiment_counts.get('Neutral', 0),
        "Negative_Tweets": sentiment_counts.get('Negative', 0),
        "Total_Tweets": len(event_tweets)
    }

# %%
result = []
for event_name, details in events.items():
    result.append(analyze_events(
        event_name,
        details['Start_Date'],
        details['End_Date'],
        details['keyword']
    ))

# %%
result_df = pd.DataFrame(result)
result_df
# Out:
#                     Event  Avg_Sentiment Sentiment_Label  Positive_Tweets  \
# 0  ChatGPT Homework surge       0.220359        Positive             1874
# 1          AI Crypto Hype       0.277149        Positive             2707
#
#    Neutral_Tweets  Negative_Tweets  Total_Tweets
# 0             933              552          3359
# 1            1217              543          4467

# %% [markdown]
# --------------

# %% [markdown]
# Temporal analysis Analysis

# %% [markdown]
# Collect tweets upon days & weeks

# %%
filtered_df = df[df['created_at'] >= '2025-02-15']

# %%
daily_tweets = filtered_df.groupby(pd.Grouper(key='created_at', freq='D')).agg({
    'Tweet': 'count', # no tweets 
    'vader_score': 'mean'  # sentiment avg 
})
daily_tweets.head()
# Out:
#             Tweet  vader_score
# created_at
# 2025-02-15   3440     0.205029
# 2025-02-16   5041     0.208978
# 2025-02-17   5162     0.205134
# 2025-02-18   3569     0.215383
# 2025-02-19   3638     0.223335

# %%
weekly_tweets = filtered_df.groupby(pd.Grouper(key='created_at', freq='W-MON')).agg({
    'Tweet': 'count',          
    'vader_score': 'mean'
  })
weekly_tweets.head()
# Out:
#             Tweet  vader_score
# created_at
# 2025-02-17  13643     0.206528
# 2025-02-24  29954     0.229504
# 2025-03-03  32124     0.264499
# 2025-03-10  32443     0.214789
# 2025-03-17  15499     0.233527

# %%
plt.figure(figsize=(20, 10))
plt.plot(daily_tweets.index, daily_tweets['vader_score'], color='#264653', label='Daily Sentiment')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(weekly_tweets.index, weekly_tweets['vader_score'], color='#264653', label='Daily Sentiment')
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# <br>

# %% [markdown]
# <h1>Visualization</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Sentiment Distribution</h2>

# %%
# Count sentiments
sentiment_counts = df['sentiment'].value_counts()
#Pie Chart
plt.figure(figsize=(8,8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['#2a9d8f','#e9c46a','#e76f51'])
plt.title('Sentiment Distribution')
plt.show()

# %% [markdown]
# <h2> Sentiment Over Time</h2>

# %%
# Already calculated daily_tweets and weekly_tweets
# Daily Sentiment
plt.figure(figsize=(14,6))
plt.plot(daily_tweets.index, daily_tweets['vader_score'], marker='o')
plt.title('Daily Sentiment Over Time')
plt.ylabel('Average Sentiment')
plt.xlabel('Date')
plt.grid(True)
plt.show()

# %%
# Weekly Sentiment
plt.figure(figsize=(14,6))
plt.plot(weekly_tweets.index, weekly_tweets['vader_score'], marker='o', color='purple')
plt.title('Weekly Sentiment Over Time')
plt.ylabel('Average Sentiment')
plt.xlabel('Week')
plt.grid(True)
plt.show()

# %% [markdown]
# <h2>NLP vs CV Sentiment Comparison</h2>

# %%
#Grouped Bar Chart (Average Sentiment)
# Data
sentiment_compare = {
    'Category': ['NLP', 'CV'],
    'Average_Sentiment': [
        nlp_tweets['vader_score'].mean(), 
        cv_tweets['vader_score'].mean()
    ]
}
compare_df = pd.DataFrame(sentiment_compare)

# Plot
plt.figure(figsize=(8,6))
sns.barplot(x='Category', y='Average_Sentiment', hue='Category', data=compare_df, palette='viridis', dodge=False, legend=False)
plt.title('Average Sentiment: NLP vs CV')
plt.ylabel('Average Sentiment Score')
plt.ylim(-1, 1)
plt.show()

# %% [markdown]
# <h2>Sentiment During Key Events</h2>

# %%
#Line plot + vertical annotations
# Base Daily Sentiment Line
plt.figure(figsize=(18,8))
plt.plot(daily_tweets.index, daily_tweets['vader_score'], label='Daily Sentiment', color='teal')

# Add vertical lines for each event
for event, details in events.items():
    plt.axvline(pd.to_datetime(details['Start_Date']), color='red', linestyle='--', alpha=0.7)
    plt.text(pd.to_datetime(details['Start_Date']), 0.9, event, rotation=90, color='red')

plt.title('Sentiment with Key Event Markers')
plt.ylabel('Average Daily Sentiment')
plt.xlabel('Date')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <h2>Most Frequent AI Keywords</h2>

# %%
#Word Cloud
from wordcloud import WordCloud

# Concatenate all tweets
all_text = ' '.join(df['Tweet'].dropna())

# Define keywords
ai_keywords = nlp_keywords + cv_keywords

# Filter only AI words appearing
ai_words = ' '.join([word for word in all_text.split() if word.lower() in [kw.lower() for kw in ai_keywords]])

# Generate Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(ai_words)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('AI Keywords WordCloud')
plt.show()

# %% [markdown]
# <h2>Tweet Volume Over Time</h2>

# %%
#Area Plot
# Daily Tweet Volume
plt.figure(figsize=(14,6))
plt.fill_between(daily_tweets.index, daily_tweets['Tweet'], color='skyblue', alpha=0.4)
plt.plot(daily_tweets.index, daily_tweets['Tweet'], color='blue')
plt.title('Tweet Volume Over Time (Daily)')
plt.ylabel('Number of Tweets')
plt.xlabel('Date')
plt.grid()
plt.show()

# %% [markdown]
# <h2>Sentiment by Keyword</h2>

# %%
# Heatmap
# Let's manually compute for each keyword
keywords = ai_keywords
keyword_sentiments = {}

for kw in keywords:
    kw_tweets = df[df['Tweet'].str.contains(kw, case=False, na=False)]
    keyword_sentiments[kw] = kw_tweets['vader_score'].mean()

# Build DataFrame
keyword_df = pd.DataFrame(keyword_sentiments.items(), columns=['Keyword', 'Avg_Sentiment'])
keyword_df = keyword_df.pivot_table(index='Keyword', values='Avg_Sentiment')

# Plot Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(keyword_df, annot=True, cmap='coolwarm', center=0)
plt.title('Sentiment by AI Keyword')
plt.show()

# %% [markdown]
# <h2>Box Plot of Sentiment Score</h2>

# %%
#Compare distribution for NLP vs CV
# Prepare Data
nlp_tweets = nlp_tweets.copy()
cv_tweets = cv_tweets.copy()

nlp_tweets['Category'] = 'NLP'
cv_tweets['Category'] = 'CV'

combined = pd.concat([nlp_tweets, cv_tweets])

# Plot
plt.figure(figsize=(10,6))
sns.boxplot(x='Category', y='vader_score', hue='Category', data=combined, palette='Set2', dodge=False, legend=False)
plt.title('Sentiment Score Distribution: NLP vs CV')
plt.ylabel('VADER Sentiment Score')
plt.ylim(-1, 1)
plt.show()
